# %% [markdown]
# # Exercise Sheet 4 - Transfer Learning for Saliency Prediction

# %% [markdown]
# * Deep Learning for Computer Vision – Winter Term 2022/23
# * Organizers: Anwai Archit, Laura Hansel, Michaela Vystrčilová, Constantin Pape
# * Tutors: Anwai Archit, Mai Elshazly, Andreas Schneider, Fabio Seel, Shashwat Sridhar
# * Due date: **Monday, Dec 19, before 14:00**

# %% [markdown]
# In this assignment you will learn how to use transfer learning to predict where people will look in images. We will work with the MIT 1003 dataset which consists of 1003 images together with fixation data from human subjects. Transfer learning allows us to reuse the features from a model that has been pretrained on a larger dataset. Here we will use VGG19 pretrained on ImageNet.
#
# The goals of this assignment are as follows:
#
# *   Extract features from a model pretrained on ImageNet.
# *   Implement a simple readout network and train it on the data.
# *   Define a loss function and a seperate evaluation metric.
# *   Visualize the best and the worst results.
#
# ## Hints
#
# To understand the idea of the exercise sheet, inspired by a paper called DeepGaze we suggest the following.
#
# * Review the lecture
# * It will be very helpful to read the according paper [Kümmerer, Theis, and Bethge (2015)](https://arxiv.org/abs/1411.1045).
#
# Although the general idea of the exercise will be the same as in the paper, we changed some details:
#    * we will use VGG instead of caffe net
#    * we will not do the same thorough analysis and
#    * other details are changed as well to make this exercise simpler.
#
# *Do not hesitate to ask questions and ideally discuss them with your fellow students and tutors on Rocket Chat! We will monitor the channel to provide you help if your discussions get stuck. Also, we are happy to help in our office hours - looking forward seeing you there!*

# %% [markdown]
# ### IMPORTANT SUBMISSION INSTRUCTIONS
#
# - When you've completed the exercise, download the notebook and rename it to `<surname1>_<surname2>_<surname3>.ipynb`
# - Only submit the Jupyter Notebook (ipynb file). No other file is required. Upload it on `Stud.IP` -> `Deep Learning for Computer Vision` -> `Files` -> `Submission of homework 3`.
# - make only one submission of the exercise per group.
# - The deadline is strict
# - In addition to the submissions, every member of your group should be prepared to present the exercise in the tutorials.
#
# Implementation
# - Only change code to replace placeholders. Leave the other code as is. In addition to the python packages loaded below you are allowed to use any packages you want.

# %% [markdown]
# ### 1. Import required libraries

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
from skimage import io, transform
import matplotlib.pyplot as plt
import os
from tqdm import tqdm
from scipy.ndimage import gaussian_filter
from torchsummary import summary
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/torch-gpu/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
def get_device(cuda_preference=False):
    """Gets pytorch device object. If cuda_preference=True and 
        cuda is available on your system, returns a cuda device.
    
    Args:
        cuda_preference: bool, default True
            Set to true if you would like to get a cuda device
            
    Returns: pytorch device object
            Pytorch device
    """
    
    print('cuda available:', torch.cuda.is_available(), 
          '; cudnn available:', torch.backends.cudnn.is_available(),
          '; num devices:', torch.cuda.device_count(),
          ';mps available:', torch.backends.mps.is_built())
    
    use_cuda = False if not cuda_preference else torch.cuda.is_available()
    use_mps = False if cuda_preference else torch.backends.mps.is_available() 

    if use_cuda: device = 'cuda:0'
    if use_mps:  device = 'mps'
    else: device = 'cpu'
    # device = torch.device(  else if use_mps: 'mps' else 'cpu')
    device_name = torch.cuda.get_device_name(device) if use_cuda else 'cpu/mps'
    print('Using device', device_name)
    return device

# %%
device = get_device()
# Out:
# cuda available: False ; cudnn available: False ; num devices: 0 ;mps available: True
# Using device cpu/mps

# %% [markdown]
# ### 2. Get the data
#
# The MIT 1003 dataset is publicly available at https://people.csail.mit.edu/tjudd/WherePeopleLook/index.html
#
# For your convenience there is a shared folder on Google Drive: https://drive.google.com/drive/folders/1GoYw3jp9kWLmHN7qylDS5QTo_ebnaMDD?usp=sharing
# You can click the link and add the folder to your Drive (it does not count into your disk quota).
#
# If you're using Kaggle (recommended) or Colab, you can uncomment the corresponding code in the following cell. With Kaggle you can download the data to your Kaggle environment. With Colab you can to mount your Google drive.

# %%
# Steps for Connecting with Google Colab
"""
# from google.colab import drive
# drive.mount('/content/drive')
# import sys
# sys.path.insert(0,'/content/drive/My Drive/Colab Notebooks/Deep Learning')
"""

# Steps for Connecting with Kaggle
"""
Run the scripts as it is by uncommenting the snippets below and it should be fine
"""
# %conda install -y gdown
# File Location - https://drive.google.com/drive/folders/1NIWYdrGCSFR86mmCBYFDgXs86TMZ9GKo?usp=sharing (we only need the id)
# !gdown --id 1NIWYdrGCSFR86mmCBYFDgXs86TMZ9GKo --folder

# unzip the mounted 
! unzip "/Users/simonblaue/ownCloud/Master/Deep Learning for Computer Vision/Exercise4/DL/ALLFIXATIONMAPS.zip" -d "MIT_1003"
! unzip "/Users/simonblaue/ownCloud/Master/Deep Learning for Computer Vision/Exercise4/DL/ALLSTIMULI.zip" -d "MIT_1003"
# Out:
# Archive:  /Users/simonblaue/ownCloud/Master/Deep Learning for Computer Vision/Exercise4/DL/ALLFIXATIONMAPS.zip
#    creating: MIT_1003/ALLFIXATIONMAPS/
#   inflating: MIT_1003/__MACOSX/._ALLFIXATIONMAPS
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1099936696_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1099936696_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2140171593_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2140171593_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2287603237_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2287603237_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2291250914_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2291250914_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_hotel_room_indoor_IMG_1098_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_hotel_room_indoor_IMG_1098_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1426163477_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1426163477_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1061875704_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1061875704_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i420400353_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i420400353_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2254450797_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2254450797_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2263796362_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2263796362_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_boston_street_april_p1010271_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_boston_street_april_p1010271_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2284954143_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2284954143_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1430672270_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1430672270_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2261687971_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2261687971_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1349055388_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1349055388_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1562869159_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1562869159_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2274296096_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2274296096_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1865602483_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1865602483_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2190511227_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2190511227_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i192592020_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i192592020_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1436876661_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1436876661_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1142164052_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1142164052_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1773927318_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1773927318_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2274292178_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2274292178_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1248920013_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1248920013_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1043252298_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1043252298_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2300237262_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2300237262_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_barcelona_street_city_outdoor_2_2005_dsc04140_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_barcelona_street_city_outdoor_2_2005_dsc04140_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2295106133_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2295106133_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i132419257_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i132419257_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i151260195_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i151260195_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1000274881_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1000274881_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1203833517_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1203833517_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2011580182_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2011580182_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2259160448_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2259160448_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1182314083_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1182314083_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1390242687_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1390242687_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i127442050_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i127442050_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i4466881_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i4466881_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1131209719_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1131209719_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_barcelona_street_city_outdoor_2_2005_dsc04265_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_barcelona_street_city_outdoor_2_2005_dsc04265_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2307584030_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2307584030_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2287732726_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2287732726_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2280648305_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2280648305_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2245334593_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2245334593_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2168982172_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2168982172_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1089044309_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1089044309_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1430117625_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1430117625_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i129682290_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i129682290_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1130504626_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1130504626_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2145018847_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2145018847_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1548942940_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1548942940_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_outdoor_bay_area_submitted_alyosha_efros_102_0213_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_outdoor_bay_area_submitted_alyosha_efros_102_0213_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i130022388_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i130022388_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2304433407_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2304433407_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i114124777_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i114124777_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_park_outdoor_boston_IMG_0134_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_park_outdoor_boston_IMG_0134_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2244493155_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2244493155_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1552375082_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1552375082_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i134585813_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i134585813_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2135366103_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2135366103_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2168018881_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2168018881_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2267703789_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2267703789_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2197089389_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2197089389_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1540552783_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1540552783_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i33894157_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i33894157_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2172150551_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2172150551_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2194959008_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2194959008_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1312550716_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1312550716_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/syntheticData2_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._syntheticData2_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i113913836_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i113913836_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i107724041_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i107724041_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1139715898_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1139715898_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1158892521_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1158892521_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1280080218_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1280080218_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_barcelona_street_city_outdoor_2005_img_0303_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_barcelona_street_city_outdoor_2005_img_0303_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i10941198_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i10941198_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1162738677_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1162738677_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2269011799_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2269011799_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1368050923_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1368050923_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i446655072_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i446655072_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2160369496_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2160369496_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2168068710_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2168068710_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i455593157_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i455593157_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i540042392_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i540042392_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2155595511_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2155595511_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i129796908_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i129796908_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2287434183_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2287434183_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1205929127_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1205929127_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2156407718_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2156407718_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1413522668_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1413522668_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/imadrid_static_street_p9110480_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._imadrid_static_street_p9110480_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2301233235_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2301233235_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1158217360_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1158217360_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2273025586_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2273025586_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i132306528_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i132306528_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2235879193_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2235879193_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_barcelona_street_city_outdoor_2_2005_img_0625_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_barcelona_street_city_outdoor_2_2005_img_0625_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i132306037_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i132306037_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_barcelona_street_city_outdoor_2_2005_img_0612_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_barcelona_street_city_outdoor_2_2005_img_0612_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2141160962_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2141160962_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1490402847_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1490402847_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2237760217_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2237760217_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2139086685_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2139086685_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1848304046_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1848304046_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1425513894_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1425513894_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2260969693_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2260969693_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2049327173_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2049327173_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2206023527_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2206023527_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2300143227_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2300143227_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i132418079_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i132418079_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i104880109_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i104880109_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2285475491_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2285475491_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2079551712_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2079551712_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2234959271_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2234959271_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i10feb04_static_cars_highland_img_0847_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i10feb04_static_cars_highland_img_0847_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_outdoor_mallorca_spain_IMG_8527_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_outdoor_mallorca_spain_IMG_8527_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2202295378_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2202295378_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2130135439_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2130135439_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_street_cambridge_outdoor_july_2005_img_0270_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_street_cambridge_outdoor_july_2005_img_0270_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_hotel_room_indoor_IMG_3208_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_hotel_room_indoor_IMG_3208_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2244589999_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2244589999_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2295551038_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2295551038_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1107247595_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1107247595_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2310037773_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2310037773_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1172413505_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1172413505_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i163125223_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i163125223_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2301799925_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2301799925_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1222460064_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1222460064_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1733818305_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1733818305_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2278136983_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2278136983_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2312211495_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2312211495_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2265609722_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2265609722_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2257748677_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2257748677_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1023439436_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1023439436_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i181096125_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i181096125_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2286511796_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2286511796_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2089736919_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2089736919_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2303119791_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2303119791_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2292751124_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2292751124_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_coast_palafrugel_outdoor_spain_IMG_9284_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_coast_palafrugel_outdoor_spain_IMG_9284_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1065169436_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1065169436_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2260967221_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2260967221_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2292794437_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2292794437_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2282543251_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2282543251_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1272119743_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1272119743_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_barcelona_street_city_outdoor_2005_img_0553_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_barcelona_street_city_outdoor_2005_img_0553_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2077402873_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2077402873_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2147250639_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2147250639_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2293362913_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2293362913_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i132416605_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i132416605_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2288352265_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2288352265_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2208329824_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2208329824_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1426598345_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1426598345_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2197948762_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2197948762_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1388275624_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1388275624_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1546500996_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1546500996_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1190302019_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1190302019_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2290865981_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2290865981_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2096842680_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2096842680_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2244455009_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2244455009_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2204386205_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2204386205_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2286138209_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2286138209_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1970328489_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1970328489_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i10feb04_static_techsquare_img_0873_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i10feb04_static_techsquare_img_0873_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1465243665_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1465243665_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2173246245_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2173246245_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i160271625_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i160271625_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1843172607_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1843172607_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1156480850_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1156480850_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i05june05_static_street_boston_p1010806_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i05june05_static_street_boston_p1010806_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2244474095_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2244474095_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2129357785_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2129357785_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1032393_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1032393_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1865070582_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1865070582_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_barcelona_street_city_outdoor_2005_img_0561_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_barcelona_street_city_outdoor_2005_img_0561_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1425519942_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1425519942_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2309143405_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2309143405_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1267668332_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1267668332_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1161381449_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1161381449_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2281390926_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2281390926_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2145575787_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2145575787_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2237729434_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2237729434_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2083298845_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2083298845_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2288435981_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2288435981_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i167462665_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i167462665_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1240539233_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1240539233_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2306664884_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2306664884_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2277680996_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2277680996_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i170746079_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i170746079_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/ibarcelona_static_street_p9140514_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._ibarcelona_static_street_p9140514_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1332346516_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1332346516_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_barcelona_street_city_outdoor_2005_img_0587_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_barcelona_street_city_outdoor_2005_img_0587_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2236294346_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2236294346_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2272663539_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2272663539_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1016451573_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1016451573_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2084420834_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2084420834_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1503092014_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1503092014_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2294701937_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2294701937_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2154989221_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2154989221_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2199632150_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2199632150_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2307207961_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2307207961_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1511249507_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1511249507_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2168660165_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2168660165_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2221608509_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2221608509_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i207806307_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i207806307_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i129772911_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i129772911_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1429029695_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1429029695_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2067966842_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2067966842_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_outdoor_road_mallorca_spain_IMG_0641_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_outdoor_road_mallorca_spain_IMG_0641_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/iseq_stereo_office_stata_oct24_img_19_00001_left_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._iseq_stereo_office_stata_oct24_img_19_00001_left_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2238238891_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2238238891_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1398733076_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1398733076_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1893435749_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1893435749_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1209163197_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1209163197_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i163823931_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i163823931_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2096251724_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2096251724_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1075466100_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1075466100_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2234097332_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2234097332_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1355286331_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1355286331_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_houses_boston_2005_IMG_4108_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_houses_boston_2005_IMG_4108_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1485351340_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1485351340_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1866531260_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1866531260_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1777084263_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1777084263_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i151492118_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i151492118_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2310105376_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2310105376_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i441015422_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i441015422_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2286398519_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2286398519_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i132306741_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i132306741_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2291666088_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2291666088_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2048557303_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2048557303_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i123476629_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i123476629_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2289711593_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2289711593_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2172895099_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2172895099_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1602482813_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1602482813_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i110996888_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i110996888_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2208022381_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2208022381_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1389946337_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1389946337_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1465015711_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1465015711_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1739584262_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1739584262_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_street_outdoor_palma_mallorca_spain_IMG_0805_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_street_outdoor_palma_mallorca_spain_IMG_0805_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2296179544_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2296179544_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1507505298_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1507505298_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2306664884_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2306664884_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1332346516_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1332346516_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/ibarcelona_static_street_p9140514_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._ibarcelona_static_street_p9140514_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2277680996_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2277680996_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i170746079_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i170746079_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2237729434_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2237729434_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i167462665_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i167462665_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2288435981_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2288435981_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1240539233_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1240539233_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2083298845_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2083298845_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2281390926_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2281390926_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1161381449_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1161381449_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2145575787_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2145575787_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2309143405_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2309143405_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1425519942_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1425519942_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_barcelona_street_city_outdoor_2005_img_0561_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_barcelona_street_city_outdoor_2005_img_0561_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1865070582_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1865070582_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1267668332_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1267668332_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1429029695_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1429029695_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i207806307_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i207806307_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i129772911_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i129772911_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1511249507_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1511249507_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2307207961_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2307207961_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2199632150_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2199632150_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2221608509_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2221608509_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2168660165_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2168660165_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1016451573_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1016451573_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2154989221_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2154989221_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2294701937_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2294701937_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1503092014_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1503092014_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2084420834_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2084420834_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2236294346_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2236294346_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_barcelona_street_city_outdoor_2005_img_0587_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_barcelona_street_city_outdoor_2005_img_0587_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2272663539_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2272663539_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_houses_boston_2005_IMG_4108_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_houses_boston_2005_IMG_4108_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1355286331_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1355286331_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2234097332_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2234097332_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1866531260_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1866531260_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1485351340_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1485351340_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2096251724_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2096251724_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i163823931_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i163823931_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1075466100_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1075466100_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1893435749_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1893435749_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1398733076_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1398733076_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1209163197_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1209163197_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2238238891_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2238238891_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/iseq_stereo_office_stata_oct24_img_19_00001_left_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._iseq_stereo_office_stata_oct24_img_19_00001_left_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_outdoor_road_mallorca_spain_IMG_0641_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_outdoor_road_mallorca_spain_IMG_0641_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2067966842_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2067966842_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_street_outdoor_palma_mallorca_spain_IMG_0805_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_street_outdoor_palma_mallorca_spain_IMG_0805_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1739584262_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1739584262_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1465015711_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1465015711_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1507505298_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1507505298_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2296179544_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2296179544_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i110996888_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i110996888_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1602482813_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1602482813_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1389946337_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1389946337_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2208022381_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2208022381_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2291666088_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2291666088_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i132306741_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i132306741_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2172895099_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2172895099_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2289711593_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2289711593_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i123476629_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i123476629_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2048557303_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2048557303_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1777084263_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1777084263_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2286398519_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2286398519_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i441015422_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i441015422_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i151492118_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i151492118_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2310105376_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2310105376_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i163125223_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i163125223_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1172413505_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1172413505_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2244589999_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2244589999_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_hotel_room_indoor_IMG_3208_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_hotel_room_indoor_IMG_3208_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2310037773_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2310037773_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2295551038_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2295551038_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1107247595_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1107247595_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2130135439_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2130135439_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2202295378_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2202295378_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_outdoor_mallorca_spain_IMG_8527_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_outdoor_mallorca_spain_IMG_8527_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_street_cambridge_outdoor_july_2005_img_0270_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_street_cambridge_outdoor_july_2005_img_0270_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_coast_palafrugel_outdoor_spain_IMG_9284_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_coast_palafrugel_outdoor_spain_IMG_9284_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2303119791_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2303119791_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2286511796_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2286511796_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2089736919_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2089736919_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2292751124_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2292751124_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2265609722_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2265609722_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i181096125_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i181096125_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1023439436_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1023439436_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2257748677_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2257748677_fixMap.jpg
# ...
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2240165147_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2240165147_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2271293627_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2271293627_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1370407372_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1370407372_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i40576393_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i40576393_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2222945716_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2222945716_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i05june05_static_street_boston_p1010785_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i05june05_static_street_boston_p1010785_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2172274186_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2172274186_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1572706519_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1572706519_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2275677162_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2275677162_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1338484745_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1338484745_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2289344696_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2289344696_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2148681608_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2148681608_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1260655983_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1260655983_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i160758712_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i160758712_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1519495464_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1519495464_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1795912442_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1795912442_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2290794919_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2290794919_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2281902585_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2281902585_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2291750140_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2291750140_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i05june05_static_street_boston_p1010855_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i05june05_static_street_boston_p1010855_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1870142757_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1870142757_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2273330095_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2273330095_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2238477160_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2238477160_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_outdoor_street_village_puigpunyent_mallorca_spain_IMG_4220_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_outdoor_street_village_puigpunyent_mallorca_spain_IMG_4220_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2258108354_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2258108354_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1817839270_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1817839270_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1000978947_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1000978947_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i14020903_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i14020903_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i110545600_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i110545600_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2305314113_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2305314113_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1236338489_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1236338489_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i05june05_static_street_boston_p1010800_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i05june05_static_street_boston_p1010800_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1246368617_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1246368617_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2057541_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2057541_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2132126218_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2132126218_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1526935589_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1526935589_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2300935113_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2300935113_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2252058417_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2252058417_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2196095208_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2196095208_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2255893801_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2255893801_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2218506905_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2218506905_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1276571229_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1276571229_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1308677325_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1308677325_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2274764417_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2274764417_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2211349766_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2211349766_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2229496653_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2229496653_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2145105890_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2145105890_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1797491266_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1797491266_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2286577669_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2286577669_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i124682633_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i124682633_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_outdoor_street_city_cambridge_uk_IMG_8687_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_outdoor_street_city_cambridge_uk_IMG_8687_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1433681776_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1433681776_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2104785691_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2104785691_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2292390104_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2292390104_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1199505141_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1199505141_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1138885959_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1138885959_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2078195666_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2078195666_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2274287237_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2274287237_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2287747547_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2287747547_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1362671223_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1362671223_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1431286095_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1431286095_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_madrid_outdoor_august_2005_img_0844_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_madrid_outdoor_august_2005_img_0844_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2206265639_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2206265639_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1872398737_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1872398737_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2257413600_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2257413600_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1206857407_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1206857407_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1461500311_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1461500311_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1507520018_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1507520018_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2170431637_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2170431637_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1130496707_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1130496707_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2253396498_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2253396498_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2240165567_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2240165567_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2127986969_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2127986969_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2174530507_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2174530507_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1032358_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1032358_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_outdoor_urban_city_street_coruna_spain_IMG_7859_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_outdoor_urban_city_street_coruna_spain_IMG_7859_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2138748225_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2138748225_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_barcelona_street_city_outdoor_2005_img_0308_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_barcelona_street_city_outdoor_2005_img_0308_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2145830934_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2145830934_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1011319098_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1011319098_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2229917843_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2229917843_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2211589033_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2211589033_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1388450272_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1388450272_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1326772343_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1326772343_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1116123355_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1116123355_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i117772445_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i117772445_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_hotel_room_indoor_IMG_0999_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_hotel_room_indoor_IMG_0999_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2166923001_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2166923001_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1433281460_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1433281460_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2286576851_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2286576851_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2285970199_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2285970199_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_outdoor_street_village_puigpunyent_mallorca_spain_IMG_4162_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_outdoor_street_village_puigpunyent_mallorca_spain_IMG_4162_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1843338577_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1843338577_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1007068829_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1007068829_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2210603425_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2210603425_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2280611353_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2280611353_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2202108776_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2202108776_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i191788956_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i191788956_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2240166669_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2240166669_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i126605331_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i126605331_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2190823731_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2190823731_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2254311605_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2254311605_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i161218845_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i161218845_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1031604161_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1031604161_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2297596765_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2297596765_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i131993073_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i131993073_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/istatic_palma_outdoor_august_2005_set2_img_1618_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._istatic_palma_outdoor_august_2005_set2_img_1618_fixPts.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i1071145422_fixMap.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i1071145422_fixMap.jpg
#   inflating: MIT_1003/ALLFIXATIONMAPS/i2305875863_fixPts.jpg
#   inflating: MIT_1003/__MACOSX/ALLFIXATIONMAPS/._i2305875863_fixPts.jpg
# Archive:  /Users/simonblaue/ownCloud/Master/Deep Learning for Computer Vision/Exercise4/DL/ALLFIXATIONMAPS.zip
# replace MIT_1003/__MACOSX/._ALLFIXATIONMAPS? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
main_path = "/Users/simonblaue/ownCloud/Master/Deep Learning for Computer Vision/Exercise4"
data_path = os.path.join(main_path, "MIT_1003")

# %% [markdown]
# ### 3. Prepare the data

# %%
images_files_all = sorted([
    os.path.join(data_path, "ALLSTIMULI", f)
    for f in os.scandir(os.path.join(data_path, "ALLSTIMULI"))
    if f.path.endswith(".jpeg")
])
print("Total Number of Images: {} (should be 1003)".format(len(images_files_all)))
# Out:
# Total Number of Images: 1003 (should be 1003)

# %%
# fix the seed for reproducible splitting
np.random.seed(1234)
train_idx = np.random.choice(len(images_files_all), len(images_files_all) // 2, replace=False)
test_idx = np.setdiff1d(np.arange(len(images_files_all)), train_idx)

images_files = {}
images_files["train"] = [images_files_all[i] for i in train_idx]
images_files["test"] = [images_files_all[i] for i in test_idx]
print("Number of Train Images: {}".format(len(images_files["train"])))
print("Number of Test Images: {}".format(len(images_files["test"])))

fixation_maps_binary_files = {}
fixation_maps_binary_files["train"] = [
    os.path.join(data_path, "ALLFIXATIONMAPS", os.path.splitext(os.path.basename(filename))[0] + "_fixPts.jpg")
    for filename in images_files["train"]
]
fixation_maps_binary_files["test"] = [
    os.path.join(data_path, "ALLFIXATIONMAPS", os.path.splitext(os.path.basename(filename))[0] + "_fixPts.jpg")
    for filename in images_files["test"]
]
fixation_maps_blurred_files = {}
fixation_maps_blurred_files["train"] = [
    os.path.join(data_path, "ALLFIXATIONMAPS", os.path.splitext(os.path.basename(filename))[0] + "_fixMap.jpg")
    for filename in images_files["train"]
]
fixation_maps_blurred_files["test"] = [
    os.path.join(data_path, "ALLFIXATIONMAPS", os.path.splitext(os.path.basename(filename))[0] + "_fixMap.jpg")
    for filename in images_files["test"]
]
# Out:
# Number of Train Images: 501
# Number of Test Images: 502

# %% [markdown]
# ### 4. Show an example from the dataset

# %%
image = io.imread(images_files["train"][0])
binary_map = io.imread(fixation_maps_binary_files["train"][0])
blurred_map = io.imread(fixation_maps_blurred_files["train"][0])
fixations = np.where(binary_map)

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
ax1.axis("off")
ax1.imshow(image)
ax2.axis("off")
ax2.imshow(blurred_map, cmap="viridis_r")
ax3.axis("off")
ax3.imshow(image, alpha=0.5)
ax3.scatter(fixations[1], fixations[0], s=1, marker=".", c="b")
ax4.axis("off")
ax4.imshow(image)
ax4.imshow(blurred_map, alpha=0.5, cmap="viridis_r")
fig.tight_layout()

# %% [markdown]
# ### 5. Preprocess images and maps
#
# The images have different sizes and orientations. To simplify our task we downscale the images and crop them to a size of 256x256 pixels. At this size, all of the images should fit into memory at once.

# %%
def preprocess_data(images_paths, fixations_binary_paths, fixations_blurred_paths, shape):
    transform = torchvision.transforms.Compose(
        [
            torchvision.transforms.ToPILImage(),
            torchvision.transforms.Resize(shape),
            torchvision.transforms.CenterCrop(shape),
        ]
    )

    n = len(images_paths)
    ims = np.empty((n, shape, shape, 3), dtype=np.int)
    fixs_binary = np.empty((n, shape, shape))
    fixs_blurred = np.empty((n, shape, shape))

    for i, path in enumerate(tqdm(images_paths)):
        image = io.imread(path)
        image = transform(image)
        image = np.array(image, dtype=np.int)
        ims[i] = image

    for i, path in enumerate(tqdm(fixations_binary_paths)):
        fixations_binary = io.imread(path, 0)
        fixations_binary = transform(fixations_binary)
        fixations_binary = np.array(fixations_binary)
        fixs_binary[i] = fixations_binary

    for i, path in enumerate(tqdm(fixations_blurred_paths)):
        fixations_blurred = io.imread(path, 0)
        fixations_blurred = transform(fixations_blurred)
        fixations_blurred = np.array(fixations_blurred)
        fixs_blurred[i] = fixations_blurred

    data = {"images": ims, "fixations_binary": fixs_binary, "fixations_blurred": fixs_blurred}
    return data

# %%
# If data is already preprocessed and saved, load it, otherwise preprocess and save it.
# If you do not whish to save the data comment the according lines.
# If you want to re-run data preprocessing, you may have to delete the saved file.

train_data_file = os.path.join(main_path, "train_data.npy")

if os.path.isfile(train_data_file):
    train_data = np.load(train_data_file, allow_pickle=True)[()]
else:
    train_data = preprocess_data(
        images_files["train"], fixation_maps_binary_files["train"], fixation_maps_blurred_files["train"], 256
    )
    np.save(train_data_file, train_data)

# %% [markdown]
# ### 6. Implement a PyTorch dataset for our data
#
# We need the `torch.utils.data.Dataset`  to access the data conveniently. Later, it is required to have access to the data through this class to build a Pytorch dataloader.

# %%
class ImageDataset(torch.utils.data.Dataset):
    def __init__(self, preprocessed_data, features=None):
        self.features = features
        self.data = preprocessed_data

    def __getitem__(self, key):
        raw_image = self.data["images"][key]

        normalized_image = raw_image.astype(np.float32) / 255.0  # -> [0, 1]
        normalized_image -= np.array([0.485, 0.456, 0.406])  # subtract mean
        normalized_image /= np.array([0.229, 0.224, 0.225])  # divide by SD
        normalized_image = normalized_image.transpose(2, 0, 1)  # HWC -> CHW

        fixations_binary = self.data["fixations_binary"][key]
        fixations_blurred = self.data["fixations_blurred"][key]

        data = {
            "raw_image": raw_image,
            "normalized_image": normalized_image,
            "fixations_binary": fixations_binary,
            "fixations_blurred": fixations_blurred,
        }

        if self.features is not None:
            data["features"] = self.features[key]

        return data

    def __len__(self):
        return len(self.data["images"])

# %% [markdown]
# The collate_fn will be used in the dataloader. It converts the batched data into tensors. We use a sparse tensor for the binary fixations because they contain mostly zeros.

# %%
def to_sparse(x):
    """converts dense tensor x to sparse format"""
    x_typename = torch.typename(x).split(".")[-1]
    sparse_tensortype = getattr(torch.sparse, x_typename)

    indices = torch.nonzero(x)
    if len(indices.shape) == 0:  # if all elements are zeros
        return sparse_tensortype(*x.shape)
    indices = indices.t()
    values = x[tuple(indices[i] for i in range(indices.shape[0]))]
    return sparse_tensortype(indices, values, x.size())


def collate_fn(batch):
    batch_data = {
        "image": torch.tensor([item["normalized_image"] for item in batch]),
        "fixations_binary": to_sparse(torch.tensor([item["fixations_binary"] for item in batch])),
        "fixations_blurred": torch.tensor([item["fixations_blurred"] for item in batch]),
    }
    if "features" in batch[0].keys():
        batch_data["features"] = torch.tensor([item["features"] for item in batch], dtype=torch.float)
    return batch_data

# %% [markdown]
# ### 7. Compute (center) bias
#
# People tend to look towards the center of the image. This is both due to a bias in our expectations as well as the tendency of photographers to place the interesting objects in the center of the photo. Thus, in the fixation data there is a bias towards the center of the image. We can calculate this bias and incorporate it into our model explicitly by using a gaussian filter on the images. The filter will always put more emphasis on what is in the center.
#
# **TO DO:** To compute the bias:
# 1. Sum all the binary fixation maps - *pixels with the highest values will be the ones where people overall looked most at*
# 1. Normalize by dividing through the maximum value - *this way we get values between 0 and 1*
# 1. Apply a Gaussian filter with standard deviation 10 to smooth the result - *smoothing is a way of regularization*
# 1. Compute the natural logarithm
#
# *Hints:*
# - Use the `ImageDataset` class to directly access the data; no pytorch data loader is required here.
# - For Gaussian filtering, you can use `gaussian_filter` from `scipy.ndimage`
#
# **Note:**
# If people had a different bias than towards the center, the steps above would also compute it. But we know the bias is towards the center, that is why it's called center bias.

# %%
from scipy.ndimage import gaussian_filter

# Instantiate the pytorch dataset. (Note that although it contains the same data,
# as `train_data` above, the objects are different. Here, we could use `train_data`)
# instead of `dataset_train`, however, to build a pytorch dataloader later, we
# have to use the `dataset_train` object.

dataset_train = ImageDataset(train_data)
fixations_binary = dataset_train.data["fixations_binary"]

# %%
fixations_sum = sum(fixations_binary)
fixations_max = np.amax(fixations_sum)
normalized_fixation_sum = fixations_sum/fixations_max

fixations_regularised = gaussian_filter(normalized_fixation_sum, sigma=10)

center_bias = np.log(fixations_regularised).reshape((1,256,256))  # (should be 1 x 256 x 256)
center_bias.shape
# Out:
# (1, 256, 256)

# %% [markdown]
# Plot the result

# %%
plt.figure()
plt.imshow(center_bias[0], cmap="viridis_r")
cb = plt.colorbar().set_label("log density")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Center bias")
# Out:
# Text(0.5, 1.0, 'Center bias')

# %% [markdown]
# Your plot should look like this:
#
# ![download.png](data:image/png;base64,...)

# %% [markdown]
# Save/Load center bias

# %%
center_bias_file = os.path.join(main_path, "center_bias.npy")

if os.path.isfile(center_bias_file):
    center_bias = np.load(center_bias_file)
else:
    np.save(center_bias_file, center_bias)

# %% [markdown]
# ### 8. Extract feature maps
#
# Load the VGG19 model pretrained on ImageNet. Use it to process the images in the train dataset: For each image, extract its feature map representation from the Conv2d layer `vgg19.features[30]`. For that, you have to constraint the vgg19 model such that all it's layers up to (including) layer 30 process the image. The subsequent layers of the model are not required to extract the feature maps. You should save them in a Numpy array of shape `(num_input_images, num_channels, x, y)`.
#
# **Theory question and hint**:
# - Which shape do you expect for the numpy array? Calculate the values by hand
# - You can verify that you calculated correctly with the code you will write for this task
#
# *Hints:*
# - Here you will have to define and use a pytorch `DataLoader` object
#     - feed in the train set of type `torch.utils.data.Dataset` created above
#     - use the `collate_fn` defined above
#     - do not shuffle the images (i.e. the data points), so we can save the feature map representations of the images. That way, we can use the feature map representations later and still identify the according image we used to create them.
# - cf. https://pytorch.org/docs/stable/torchvision/models.html. If you are wondering if we normalized images, check code in `ImageDataset`
# - Define a `feature_extractor` object, containing those parts of the pre-trained VGG19 models that you need to extract the feature map representations from the Conv2d layer `vgg19.features[30]`
#     - Don't forget to put your feature extractor in evaluation mode
#     - To avoid problems with memory, you can wrap the feature extraction with `torch.no_grad

# %%
#TODO
vgg = models.vgg19(weights='DEFAULT', progress=True)
feature_extractor = vgg.features[:31]
feature_extractor.eval()
data_loader = torch.utils.data.DataLoader(dataset_train, collate_fn=collate_fn, shuffle=False)

# %%
@torch.no_grad()
def compute_train_features():
    num_input_images = 501
    num_channels = 512
    x = 16
    y = 16
    features = np.zeros((num_input_images, num_channels, x ,y))
    for i,data in enumerate(iter(data_loader)):
        img = data["image"]
        feature = feature_extractor(img)
        features[i] = feature.numpy()

    return features

# %%
features = compute_train_features()

# %%
features[0, 0, :10, :10]

my_first = np.array(
  [[ -5.05856466,  -5.4494257 ,  -4.04796982,  -4.00965071,
         -3.81041718,  -3.70049286,  -3.46916485,  -3.33066034,
         -3.46696043,  -3.73726797],
       [ -6.30921459,  -6.64189482,  -4.25930071,  -3.9821887 ,
         -3.24017787,  -3.00728607,  -2.99680424,  -3.60748792,
         -4.02912855,  -4.39249754],
       [ -3.42979932,  -3.04783916,  -2.05231786,  -2.40027452,
         -1.40099442,  -0.51563579,   0.20034136,  -0.37016311,
         -0.84697855,  -1.10821533],
       [ -4.69450712,  -4.35959959,  -2.98953509,  -2.70575833,
         -2.62578821,  -2.11511731,  -0.68794405,  -0.5882737 ,
         -0.71196538,  -0.81783384],
       [ -4.76338768,  -6.21356106,  -5.29625702,  -5.73660183,
         -5.6103754 ,  -4.53766441,  -2.57118201,  -1.17775786,
          0.11070804,   0.5702228 ],
       [ -4.61159134,  -7.80155039,  -7.14027405,  -9.02618408,
         -9.96448708,  -9.96776295,  -7.93923092,  -4.81323004,
         -1.49802494,   0.16369674],
       [ -1.97690332,  -5.6039896 ,  -5.94019222,  -8.35468102,
         -8.34007359, -10.02152061, -10.62399673,  -8.92269897,
         -4.96324825,  -2.63385153],
       [ -2.03595066,  -5.86262941,  -5.21619272,  -3.86745334,
         -2.13602352,  -4.00327969,  -7.24868965,  -9.66466236,
         -9.5114603 ,  -8.05636787],
       [ -0.08571764,  -2.13494325,  -2.18564367,  -2.4991262 ,
         -1.99604654,  -2.62563753,  -5.04191589,  -7.47077799,
         -8.94376183,  -9.34239388],
       [  2.41950822,   1.38582611,   0.01735599,  -5.72051001,
         -5.90603733,  -4.65355492,  -6.06961203,  -7.60494852,
         -8.39218616,  -8.17572308]])
# Out:
# array([[ -5.05856466,  -5.4494257 ,  -4.04796982,  -4.00965071,
#          -3.81041718,  -3.70049286,  -3.46916485,  -3.33066034,
#          -3.46696043,  -3.73726797],
#        [ -6.30921459,  -6.64189482,  -4.25930071,  -3.9821887 ,
#          -3.24017787,  -3.00728607,  -2.99680424,  -3.60748792,
#          -4.02912855,  -4.39249754],
#        [ -3.42979932,  -3.04783916,  -2.05231786,  -2.40027452,
#          -1.40099442,  -0.51563579,   0.20034136,  -0.37016311,
#          -0.84697855,  -1.10821533],
#        [ -4.69450712,  -4.35959959,  -2.98953509,  -2.70575833,
#          -2.62578821,  -2.11511731,  -0.68794405,  -0.5882737 ,
#          -0.71196538,  -0.81783384],
#        [ -4.76338768,  -6.21356106,  -5.29625702,  -5.73660183,
#          -5.6103754 ,  -4.53766441,  -2.57118201,  -1.17775786,
#           0.11070804,   0.5702228 ],
#        [ -4.61159134,  -7.80155039,  -7.14027405,  -9.02618408,
#          -9.96448708,  -9.96776295,  -7.93923092,  -4.81323004,
#          -1.49802494,   0.16369674],
#        [ -1.97690332,  -5.6039896 ,  -5.94019222,  -8.35468102,
#          -8.34007359, -10.02152061, -10.62399673,  -8.92269897,
#          -4.96324825,  -2.63385153],
#        [ -2.03595066,  -5.86262941,  -5.21619272,  -3.86745334,
#          -2.13602352,  -4.00327969,  -7.24868965,  -9.66466236,
#          -9.5114603 ,  -8.05636787],
#        [ -0.08571764,  -2.13494325,  -2.18564367,  -2.4991262 ,
#          -1.99604654,  -2.62563753,  -5.04191589,  -7.47077799,
#          -8.94376183,  -9.34239388],
#        [  2.41950822,   1.38582611,   0.01735599,  -5.72051001,
#          -5.90603733,  -4.65355492,  -6.06961203,  -7.60494852,
#          -8.39218616,  -8.17572308]])

# %% [markdown]
# ### 9. Save the features to a file
#
# Processing the images can take a few minutes. However, you only have to do it once. Thus it is a good idea to save the features to a file that you can load again later.

# %%
features_file = os.path.join(main_path, "features_train.npy")

if os.path.isfile(features_file):
    features = np.load(features_file)

else:
    features = compute_train_features()

    # sanity check:
    # in the 1st feature map, is the 10 x 10 matrix defined by the first 10
    # height and width entries computed correctly?
    # fmt: off
    expected_values = np.array(
    [[ -5.05856514,  -5.4494257 ,  -4.04797173,  -4.00965357,
         -3.81041431,  -3.70049334,  -3.4691658 ,  -3.33066201,
         -3.46696138,  -3.73726773],
       [ -6.3092165 ,  -6.64189959,  -4.25930309,  -3.98219156,
         -3.24017859,  -3.00728726,  -2.9968071 ,  -3.60749149,
         -4.02913189,  -4.39249563],
       [ -3.42980075,  -3.04784107,  -2.05232024,  -2.40027595,
         -1.40099525,  -0.51563621,   0.20033906,  -0.37016585,
         -0.84697777,  -1.10821617],
       [ -4.69450617,  -4.35960007,  -2.98953676,  -2.70576119,
         -2.62578845,  -2.11511397,  -0.68794125,  -0.58827341,
         -0.71196592,  -0.81783342],
       [ -4.76338863,  -6.2135601 ,  -5.2962575 ,  -5.73660374,
         -5.61037779,  -4.53765774,  -2.5711813 ,  -1.17775714,
          0.11070768,   0.57022107],
       [ -4.61159277,  -7.80154657,  -7.14027071,  -9.02617931,
         -9.96448612,  -9.96775627,  -7.93922615,  -4.81323099,
         -1.49802375,   0.16369806],
       [ -1.97690308,  -5.60399246,  -5.94019413,  -8.35467911,
         -8.34007072, -10.02152252, -10.62400055,  -8.92269707,
         -4.9632473 ,  -2.63384819],
       [ -2.03594875,  -5.8626318 ,  -5.21619272,  -3.86745071,
         -2.13602161,  -4.00327349,  -7.24868536,  -9.66466331,
         -9.5114603 ,  -8.05636787],
       [ -0.08571954,  -2.13494349,  -2.18564558,  -2.49912596,
         -1.9960444 ,  -2.62563705,  -5.04191208,  -7.47077799,
         -8.94375992,  -9.3424015 ],
       [  2.41950774,   1.38582683,   0.01735479,  -5.72050619,
         -5.90604067,  -4.65355062,  -6.06961155,  -7.60495043,
         -8.39218903,  -8.17572594]]
    )
    # fmt: on
    assert np.allclose(features[0, 0, :10, :10], expected_values), "Feature maps look different than expected"

    np.save(features_file, features)

# %% [markdown]
# Add the features to the dataset and define a data loader for training our model. Feel free to change the batch size.

# %%
dataset_train = ImageDataset(train_data, features=features)

data_loader_train = torch.utils.data.DataLoader(
    dataset_train,
    shuffle=True,
    batch_size=128,
    collate_fn=collate_fn,
    pin_memory=False,
)

# %% [markdown]
# ### 10. Define the model
#
# Now we need to define the model we want to train. Two parts are necessary:
#
# 1. Readout Network
#
# The readout network gets the feature maps we extracted from VGG19 as input. The network could be of arbitrary complexity but in our case we want to keep it simple: it contains only one layer that takes a linear combination of the features at each location (using 1x1 convolution).
#
# 2. Finalizer
#
# The finalizer takes the output of the readout network and scales it up to the size of our images (256x256). It then applies a Gaussian filter to blur the result of the upscaling and adds the center bias. Finally, it performs normalization using a (log) softmax to return the logarithm of the fixation probability densities, later refered to as `log_density`.
#
# *Hints:*
# - What are in- and out-shapes of the readout network? What are the parameters you have to pass to the constructor of the 1x1 convolution, then?
# - Don't forget to give a learnable weight to the center bias, $\alpha$ in [Kümmerer, Theis, and Bethge (2015)](https://arxiv.org/abs/1411.1045).
# - In `Finalizer` below, initialize `self.gaussian_blur = GaussianBlur2d()` and use `self.gaussian_blur` in `forward(...)`.
# - You might want to use `F.interpolate` to scale up the images after the readout network
# - The finalizer output is of shape `(batch, x_pixels, y_pixels)`
# - Use vectorized and torch functions (not for loops)
# - Log softmax: The finalizer should return the logarithm of the fixation probabilities. Here is how to rewrite the math of the paper cited above accordingly:
#
# $$ \ln p(x, y)=\ln \frac{\exp (o(x, y))}{\sum_{x, y} \exp (o(x, y))} = o(x, y)-\ln{\sum_{x, y} \exp (o(x, y))} $$
#
# Where $ p(x,y) $ referst to the probability of a fixation at a certain pixel position $ (x,y) $ and $ o(x,y) $ is the output of the finalizer.
# (Note that in the paper $\log$ refers to the natural logarithm $\ln$. The paper also adds a regularization term which we can ignore in this step). We recommend you to use `logsumexp` to compute the softmax in log-space.

# %%
class GaussianBlur2d(nn.Module):
    """
    This class applies a Gaussian filter to a tensor. You should 
    use it *after* upscaling to image size (256x256). The kernel
    size and the standard deviation are fixed and you don't need
    to change them.
    """
    
    def __init__(self):
        super().__init__()

        self.kernel_size = 121
        self.sigma = 20
        self.pad = 60

        grid = torch.arange(float(self.kernel_size)) - self.pad

        kernel_shape = [self.kernel_size]
        grid = nn.Parameter(grid.view(kernel_shape), requires_grad=False)
        kernel = torch.exp(-0.5 * (grid / self.sigma) ** 2)
        kernel = kernel / kernel.sum()
        self.kernel_x = nn.Parameter(kernel[None, None, :, None], requires_grad=False)
        self.kernel_y = nn.Parameter(kernel[None, None, None, :], requires_grad=False)
        
    def forward(self, tensor):
        """Applies the gaussian filter to the given tensor"""
        out = F.conv2d(tensor, self.kernel_x, padding=self.pad)
        out = F.conv2d(out, self.kernel_y)

        return out

# %%
readout_network = nn.Conv2d(in_channels=512, out_channels=1, kernel_size=1)

# %%
class Finalizer(nn.Module):
    """Returns logarithm of the fixation probability densities, shape: (batch, x_size, y_size)"""
    
    def __init__(self) -> None:
        super().__init__()
        
        self.gaussian_blur = GaussianBlur2d()
        self.alpha = nn.Parameter(torch.rand(1,1))
        
    def forward(self, x, centerbias):
        x = F.interpolate(x, size=(256,256))
        x = self.gaussian_blur(x)
        x = torch.matmul((self.alpha * centerbias),x)
        x = x - torch.logsumexp(x, dim=(-2,-1), keepdim=True)
        return x

# %%
class Model(nn.Module):
    def __init__(self, readout_network, finalizer):
        super().__init__()
        self.readout_network = readout_network
        self.finalizer = finalizer

    def forward(self, x, centerbias):
        x = self.readout_network(x)
        x = self.finalizer(x, centerbias)
        return x

    def train(self, mode=True):
        self.readout_network.train(mode=mode)
        self.finalizer.train(mode=mode)

# %%
finalizer = Finalizer()
model = Model(readout_network, finalizer)

# %% [markdown]
# ### 11. Define the metrics
#
# We use two different metrics, one for training and one for evaluating the performance of our model. Remember that we did this for the past exercises, too: back then, we used the cross-entropy loss for training and accuracy for validation.
#
# Here, for the training, we use the **negative log-likelihood (NLL)**. Implement a function that calculates the negative log-likelihood of a fixation mask (which are the labels in our data) under the model prediction `log_density` (i.e. the logarithm of the fixation probability density maps).
#
# *Hints:*
# The negative log-likelihood we want to use is a slight modification of the equation (last one on page 3) given in Kümmerer, Theis, and Bethge (2015): we ignore the regularization term. Hence, we obtain
#
# $$c(\alpha, w)=-\frac{1}{N} \sum_{i=1}^{N} \ln \hat{p}\left(x_{i}, y_{i}\right) \ .$$
#
# In the NLL we evaluate the model's predictions. Our model predicts the fixation probability $\hat{p}$ at the positions $(x,y)$. We want to compare it to the number of fixations at these positions in our labeled data. Note that the elements in the binary fixation masks $f(x_j, y_k)$ (our labels) count how many fixations ocurred at position $(x_j, y_k)$.
#
# Let's rewrite the NLL in a way you can directly implement into code: We compute the inner product of the model predictions $\hat{p}(x_j, y_k)$ and ground truth binary fixation masks $f(x_j, y_k)$ (they have the same shape) and divide by the fixation count $N$. Additionally, we compute the mean over images $b$ in our batch. This way, we obtain
#
# $$\tilde{c}(\alpha, w) = \frac{1}{b} \sum_b^B \underbrace{ (-1) \frac{1}{N} \sum_{j,k} \ln (\hat{p}(x_{j}, y_{k} |\, \mathrm{image} \ b)) \cdot f(x_{j},y_{k} |\, \mathrm{image} \ b) }_{c(\alpha, w)} \ .$$
#
# **Note:**
# - The conditioning on the image is there to express that the probability of fixations we predict is conditioned, i.e. depends on the image for which we are predicting the fixations.
#
# **Questions:**
# - Why can we re-write the expression $c(\alpha, w)$ like this?
# - What values can the elements of $f(x_{j},y_{k} |\, \mathrm{image} \ b)$ obtain?
# - On the lecture slides the loss contained a *sum* over images. Here, for practical reasons we compute the *mean* over images instead. Why is that advantageous?
#
# Implement $\tilde{c}(\alpha, w)$. You may want to
# - Convert the sparse binary `fixation_mask` to a dense one using `t.to_dense()` to be able to compute the inner product of $f$ with the predictions $\hat{p}$.
# - Compute the mean across batches

# %%
def neg_log_likelihood(log_predictions, fixation_mask):
    N = torch.sum(fixation_mask.to_dense(), dim=(-1,-2))
    fixation_mask = fixation_mask.to_dense().reshape(-1,1,256,256)
    c = -torch.matmul(log_predictions, fixation_mask).reshape(-1,256,256)
    c /= N.reshape(-1,1,1)
    return torch.mean(c)

# %% [markdown]
# For evaluation, we want to use the *normalized scanpath saliency* (NSS; [Peters, Iyer, Itti, and Koch (2005), Section 2.10](https://doi.org/10.1016/j.visres.2005.03.019)). To compute NSS, normalize the model's saliency map which is the model's prediction $\mathrm{SM}(x,y)$ to have zero mean and unit standard deviation,
#
# $$Z_{\mathrm{SM}}(x,y) = \frac{\mathrm{SM}(x,y) - \mu}{\sigma}\ ,$$
#
# where $\mu$ and $\sigma$ are the mean and the standard deviation of the saliency map, respectively. Then, average the according responses at all fixations $(x_i,y_i)$,
#
# $$\mathrm{NSS} = \frac{1}{b} \sum_b^B {(\frac{1}{N} \sum_{j,k} {Z_{SM}}(x_{j}, y_{k} |\, \mathrm{image} \ b) \cdot f(x_{j},y_{k} |\, \mathrm{image} \ b))}\ $$
#
# Implement this as a function.
#
# *Hints:*
# - For the evaluation of this metric, the saliency map $\mathrm{SM}(x,y)$ is *not* supposed to be in log-space. Therefore the saliency map should be given an exponential of the `log_predictions`: $\mathrm{e}^{\hat{p}(x, y)}$.
# - Remember the hints from above:
#     - Compute the mean across batches

# %%
def nss(log_predictions, fixation_mask):
    N = torch.sum(fixation_mask.to_dense(), dim=(-1,-2))
    fixation_mask = fixation_mask.to_dense().reshape(-1,1,256,256)
    predictions = torch.exp(log_predictions)
    Z_sm = predictions - torch.mean(predictions, dim=(-1,-2)).reshape(-1,1,1,1)/(torch.std(predictions, dim=(-1,-2))).reshape(-1,1,1,1)
    c = torch.matmul(Z_sm, fixation_mask).reshape(-1,256,256)
    c /= N.reshape(-1,1,1)
    return torch.mean(c)

# %% [markdown]
# ### 12. Train the model
#
# Now iterate through the dataloader to train the model on the train dataset. You can use the Adam optimizer with default parameters. You should print the NLL and the NSS of the train dataset after each training epoch to monitor the progress. Train for at least 5 epochs. You are welcome to reuse and adapt the code you used on the previous exercise sheets for model training, but you don't have to.
#
# *Hints:*
# - Do we want to maximize or minimize the negative log-likelihood?
# - In our reference implementation, after the fifth epoch we got `NLL: 10.0   NSS: 3.9`

# %%
def run_training(model, train_dataset, centerbias):
    optimizer = torch.optim.Adam(model.parameters())
    num_epochs = 5
    
    for i in range(num_epochs):
    
        for data in train_dataset:
            
            x = data["features"]
            y = data["fixations_binary"]
            optimizer.zero_grad()
            model.train()
            
            # Forward pass
            y_pred = model(x, centerbias)

            # Compute loss
            nll = neg_log_likelihood(y_pred.float(), y.float())
            nss_var = nss(y_pred.float(), y.float())
            
            loss = -nll
    
            # Backward pass
            loss.backward()
            optimizer.step()

        print(f"In iteration {i+1}, NLL: {nll}, NSS: {nss_var}")

# %% [markdown]
# You can save the model to disk if you want to.

# %%
model_file = os.path.join(main_path, 'model_name.torch')

if os.path.isfile(model_file):
    model.load_state_dict(torch.load(model_file))
    model.eval()
else:
    run_training(model, data_loader_train, torch.tensor(center_bias, dtype=torch.float))
    torch.save(model.state_dict(), model_file)
# Out:
# /var/folders/1f/gmftnv0j09z43wy7yh582c0m0000gn/T/ipykernel_15728/3238535079.py:16: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:233.)
#   "image": torch.tensor([item["normalized_image"] for item in batch]),
# In iteration 1, NLL: 0.6192290186882019, NSS: -9.088557999348268e-05
# In iteration 2, NLL: 1.5348072052001953, NSS: -6.177474278956652e-05
# In iteration 3, NLL: 2.7962987422943115, NSS: -4.6625660615973175e-05
# In iteration 4, NLL: 4.064939975738525, NSS: -3.8403002690756693e-05
# In iteration 5, NLL: 6.1331024169921875, NSS: -3.3313699532300234e-05

# %% [markdown]
# ### 13. Get the scores for the test data

# %%
test_data = preprocess_data(
    images_files["test"], fixation_maps_binary_files["test"], fixation_maps_blurred_files["test"], 256
)

# %% [markdown]
# Here you need to extract the same feature maps as you extracted before, but now for the test images instead of the training images. It works the same way as before for the train dataset.

# %%
def compute_test_features():
    # TODO

# %% [markdown]
# save / load

# %%
features_test_file = os.path.join(main_path, "features_test.npy")

if os.path.isfile(features_test_file):
    features_test = np.load(features_test_file)
else:
    features_test = compute_test_features()
    np.save(features_test_file, features_test)

# %% [markdown]
# Get the NSS scores for each test image. Print the three highest NSS scores. In our reference implementation, we got `[6.0, 7.1, 7.3]`.

# %%
dataset_test = ImageDataset(test_data, features=features_test)

data_loader_test = torch.utils.data.DataLoader(
    dataset_test,
    shuffle=False,
    batch_size=8,
    collate_fn=collate_fn,
    pin_memory=False,
)

# %%
#TODO
scores =

# %% [markdown]
# ### 14. Inspect the results
#
# Let's find out how well your model performs. Use the given plot function to visualize the saliency maps for
# 1. the three elements of the test dataset with the *highest NSS* and
# 2. the three elements of the test dataset with the *lowest NSS*.
#
# Print the respective NSS values.

# %% [markdown]
# **Display test images with highest scores**
#
# For the images with the highest scores the predicted saliency map should look very similar to the observed fixation map.
#
# Here is an example:
#
# ![alt text](https://i.imgur.com/qgUQG2W.png)

# %%
def plot(image, fixations, blurred_map, prediction):
    fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2, 3)

    ax1.axis("off")
    ax1.imshow(image)
    ax1.set_title("original image")

    ax2.axis("off")
    ax2.imshow(blurred_map, cmap="viridis_r")
    ax2.set_title("blurred fixation map")

    ax3.axis("off")
    ax3.imshow(prediction, cmap="viridis_r")
    ax3.set_title("model prediction")

    ax4.axis("off")
    ax4.imshow(image, alpha=0.5)
    ax4.scatter(fixations[1], fixations[0], s=10, marker=".", c="b")
    ax4.set_title("overlayed with discrete fixations")

    ax5.axis("off")
    ax5.imshow(image)
    ax5.imshow(blurred_map, alpha=0.5, cmap="viridis_r")
    ax5.set_title("overlayed with original image")

    ax6.axis("off")
    ax6.imshow(image)
    ax6.imshow(prediction, alpha=0.5, cmap="viridis_r")
    ax6.set_title("overlayed with original image")

# %%
# TODO

# %% [markdown]
# **Display test images with lowest scores**
#
# Here is an example for which the prediction is poor:
#
# ![alt text](https://i.imgur.com/g4rD2O1.png)

# %%
# TODO
